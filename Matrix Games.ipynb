# %%
# if you don't have some package, install it right here with 
# import Pkg; Pkg.add("Name of the Package")
using LinearAlgebra: norm, opnorm, svdvals, eigvals
using Plots 
using JLD2 # for saving data. One can comment it

include("problem_instances.jl")
using .Problems

# %% [markdown]
# ## Euclidean run
#
#
# | id  | function  | n  |   |   |
# |---|---|---|---|---|
# |probl_1| policeman_and_burglar_matrix  |  500 |   |   |
# |probl_2| nemirovski1  | 500  |   |   |
# |probl_3| nemirovski2   | 500  |   |   |
#
# The first problem is randomly generated. For the paper we used seed `sd="1"`. Set `sd="false"` otherwise. For the first run of code set `m, n, N` small

# %%
# Choose dimensions and problem instance
m, n = 50, 50

probl = 1 # 1, 2 or 3
sd = "1"


if probl == 1
    A = Problems.policeman_and_burglar_matrix(n; seed=sd)
    filename = "save/probl_1e.jld2" 
elseif probl == 2
    A = Problems.nemirovski1(n)
    filename = "save/probl_2e.jld2" 
elseif probl == 3
    A = Problems.nemirovski2(n, 2)
    filename = "save/probl_3e.jld2"
elseif probl == 4
    A = Problems.randunif(m, n; seed=sd)
    filename = "save/probl_4e.jld2"
    
end
       

# Compute different norms of A
max_norm = maximum(abs.(A))
l2_norm = norm(A, 2)
sp_norm = opnorm(A)
print("Operator norm of A is $(round(sp_norm, digits=1)),
Frobenius norm is $(round(l2_norm, digits=1)),
max norm is $(round(max_norm, digits=1))")

x0 = ones(n)/n 
y0 = ones(m)/m

z0 = [x0; y0]
tol = 1e-8

# deterministic algorithms
step_dtr = 0.99 / sp_norm

# proposed variance reduction
K = ceil(Int64, 2*m*n/(m + n))
p = 1.0 / K
α = 1 - p
step_vr = 0.99 * sqrt(p) / l2_norm

# proposed variance reduction-looped
K = ceil(Int64, 2*m*n/(m + n))
p = 1.0 / K
α = 1 - p
step_vr = 0.99 * sqrt(p) / l2_norm

# Carmon et al. Euclidean setting
step_mult = 4.0 
alpha_ = l2_norm * sqrt((m + n)/(2 * m * n))
η = alpha_ / (step_mult * l2_norm^2);
# Out:
# Operator norm of A is 45.9,
# Frobenius norm is 46.5,
# max norm is 2.3

# %% [markdown]
# #### Set number of epochs `N` and run the algorithms

# %%
include("algorithms.jl")
projection(x) = proj_simplex1(x)

N = 1000
@time res1 = extraGrad(A, projection, z0, step_dtr, N, tol=tol)
@time res2 = stochMPCarmon(A, projection, z0, alpha_, η, N, distr=true, tol=tol)
@time res3 = stochExtraGradLooped(A, projection, z0, step_vr, α, K, N,
            bregman=false, distr=true, tol=tol)
@time res4 = stochExtraGradLoopless(A, projection, z0, step_vr, α, p, N,
            bregman=false, distr=true, tol=tol);

@save filename res1 res2 res3 res4
# Out:
#   1.046132 seconds (2.17 M allocations: 129.390 MiB, 5.00% gc time, 99.14% compilation time)
#   3.130937 seconds (5.21 M allocations: 482.810 MiB, 6.47% gc time, 89.62% compilation time)
#   1.311246 seconds (1.15 M allocations: 251.942 MiB, 4.91% gc time, 74.21% compilation time)
#   1.673385 seconds (2.46 M allocations: 307.276 MiB, 6.41% gc time, 83.17% compilation time)

# %% [markdown]
# Timing is not important here, since we compare algorithms' performance with respect to arithmetic operations. And of course our VR-implmentation is not so good.

# %% [markdown]
# #### Make a quick plot

# %%
gr()

# some hack to put markers less frequently. From https://github.com/JuliaPlots/Plots.jl/issues/2523#issuecomment-607090470
# now their frequency is controled by parameter `step`

@recipe function f(::Type{Val{:samplemarkers}}, x, y, z; step = 500)
    n = length(y)
    sx, sy = x[1:step:n], y[1:step:n]
    # add an empty series with the correct type for legend markers
    @series begin
        seriestype := :path
        markershape --> :auto
        x := [Inf]
        y := [Inf]
    end
    # add a series for the line
    @series begin
        primary := false # no legend entry
        markershape := :none # ensure no markers
        seriestype := :path
        seriescolor := get(plotattributes, :seriescolor, :auto)
        x := x
        y := y
    end
    # return  a series for the sampled markers
    primary := false
    seriestype := :scatter
    markershape --> :auto
    x := sx
    y := sy
end
### end of hack

labels = ["EG","EG-Car+19", "EG-Alg2", "EG-Alg1"]
plot(res1[1], yaxis=:log, label=labels[1], legend=:topright, linewidth=2,marker=:auto, seriestype=:samplemarkers, step=50, xlabel = "epoch", ylabel = "Duality gap")
plot!(res2[4], res2[1], label=labels[2], linewidth=2,marker=:auto, seriestype=:samplemarkers, step=10)
plot!(res3[4], res3[1], label=labels[3], linewidth=2, marker=:auto, seriestype=:samplemarkers, step=50)
plot!(res4[4], res4[1], label=labels[4], linewidth=2, marker=:utriangle, seriestype=:samplemarkers, step=45)

# %% [markdown]
# For publication we used backend `PGFPlotsX`. It is slightly more complicated, so we put that code [below](#plots_publish) the Bregman case.

# %% [markdown]
# ## Bregman run
# All problems are the same.

# %%
# Choose dimensions and problem instance
m, n = 50, 50


probl = 1 # 1, 2 or 3
sd = "1"

if probl == 1
    A = Problems.policeman_and_burglar_matrix(n; seed=sd)
    filename = "save/probl_1b.jld2" 
elseif probl == 2
    A = Problems.nemirovski1(n)
    filename = "save/probl_2b.jld2" 
elseif probl == 3
    A = Problems.nemirovski2(n, 2)
    filename = "save/probl_3b.jld2" 
elseif probl == 4
    A = Problems.randunif(m, n; seed=sd)
    filename = "save/probl_4b.jld2"
    
end



# Compute different norms of A
max_norm = maximum(abs.(A))
l2_norm = norm(A, 2)
sp_norm = opnorm(A)
print("Operator norm of A is $(round(sp_norm, digits=1)),
Frobenius norm is $(round(l2_norm, digits=1)),
max norm is $(round(max_norm, digits=1))")

x0 = ones(n)/n 
y0 = ones(m)/m
z0 = [x0; y0]
tol = 1e-8

# deterministic algorithm
step_dtr_br = 0.99 / max_norm

# proposed variance reduction
K = ceil(Int64, 2*m*n/(m + n))
p = 1.0 / K
α = 1 - p
step_vr_br = 0.99 * sqrt(p) / max_norm

# proposed variance reduction-looped
K = ceil(Int64, 2*m*n/(m + n))
p = 1.0 / K
α = 1 - p
step_vr_br = 0.99 * sqrt(p) / max_norm

# Carmon et al. Bregman setting
step_mult = 10.0 
alpha_br = max_norm * sqrt((m + n)/(2 * m * n))
η_br = alpha_br / (step_mult * max_norm^2);
# Out:
# Operator norm of A is 45.9,
# Frobenius norm is 46.5,
# max norm is 2.3

# %% [markdown]
# #### Set number of epochs `N` and run the algorithms

# %%
include("algorithms.jl")

b = 10
N = 10000
gamma = min(1 / 16, b / n)
eigvs = eigvals(A)
L = maximum(eigvs)
println("L = $L")
#println(minimum(svdvals(A)))
eta = min(sqrt(gamma * b) / 2 / L, 1 / 8 / L)

@time res1 = extraGrad_bregman(A, z0, step_dtr_br, N, tol=tol) 
@time res2 = stochMPCarmon(A, projection, z0, alpha_br, η_br, N, distr=true, bregman=true, tol=tol);
@time res3 = MirProxVR(A, z0, step_vr_br, α, K, N, tol=tol);
@time res4 = stochAlgorithm2Bregman(A, projection,
    z0, z0, gamma, eta, gamma, b, K, N; distr=false, tol=tol)

@save filename res1 res2 res3
# Out:
# L = 35.25075680539655
#   0.372848 seconds (422.37 k allocations: 43.433 MiB, 4.86% gc time, 82.37% compilation time)
# Stochastic Carmon algorithm achieved 1.0e-8 accuracy
#   4.189203 seconds (6.76 M allocations: 2.588 GiB, 10.18% gc time, 28.48% compilation time)
# StochMirProx-VR algorithm achieved 1.0e-8 accuracy
#   1.426558 seconds (2.69 M allocations: 893.899 MiB, 10.25% gc time, 44.14% compilation time)
#  16.528436 seconds (26.78 M allocations: 9.461 GiB, 7.94% gc time, 21.08% compilation time)

# %%
gr()
labels = ["MP","MP-Car+19", "MP-Alg2", "Andrei"]
plot(res1[1], yaxis=:log, label=labels[1], legend=:bottomleft, linewidth=2,marker=:auto, seriestype=:samplemarkers, step=50, xlabel = "epoch", ylabel = "Duality gap")
plot!(res2[4], res2[1], label=labels[2], linewidth=2,marker=:auto, seriestype=:samplemarkers, step=10)
plot!(res3[4], res3[1], label=labels[3], linewidth=2, marker=:auto, seriestype=:samplemarkers, step=50)
plot!(res4[4], res4[1], label=labels[4], linewidth=2, marker=:auto, seriestype=:samplemarkers, step=50)

# %% [markdown]
# <a id='plots_publish'></a>
#
# ### Plots for publishing
#
# First choose the problem and load data

# %%
using PGFPlotsX
using LaTeXStrings
#import Pkg; Pkg.add("LaTeXStrings")

# load data 
probl = 1 # 1, 2 or 3
sd = "1"

if probl == 1
    A = Problems.policeman_and_burglar_matrix(n; seed=sd)
    filename = "save/probl_1e.jld2" 
elseif probl == 2
    A = Problems.nemirovski1(n)
    filename = "save/probl_2e.jld2" 
elseif probl == 3
    A = Problems.nemirovski2(n, 2)
    filename = "save/probl_3e.jld2" 
elseif probl == 4
    A = Problems.randunif(m, n; seed=sd)
    filename = "save/probl_4e.jld2"
    
end

@load filename res1 res2 res3 res4
# Out:
# 4-element Array{Symbol,1}:
#  :res1
#  :res2
#  :res3
#  :res4

# %%
y1, y2, y3, y4 = res1[1], res2[1], res3[1], res4[1]
x1, x2, x3, x4 = Array(1:length(y1)), res2[4], res3[4], res4[4]


fig = @pgf Axis(
    {
        xmajorgrids, # show grids along x axis
        ymajorgrids, 
        xlabel = L"\Large{\mbox{epoch}}",  
        ylabel = L"\Large{\mbox{Duality gap}}",
        #xmode  = "log",
        ymode  = "log",
        "mark size=4pt",
        width = raw"1\textwidth",
        height = raw"0.8\textwidth",
        
        "axis background/.style" = { fill = "gray!10" }, 
   
    },
    PlotInc(
        {
            #"no marks",
            "mark repeat=1000",
            style = "{very thick}",
        },
        Coordinates(x1, y1)
    ), 
   LegendEntry(L"\Large{\mbox{EG}}"),
   
    PlotInc(
        {
            #"no marks",
            "mark repeat=200",
            style = "{very thick}",
        },
        Coordinates(x2, y2)
    ),
  LegendEntry(L"\Large{\mbox{EG-Car+19}}"),
    
       
    PlotInc(
        {
            #"no marks",
            "mark repeat=400",
            mark="triangle*",
            style = "{very thick}",
            color = "olive" 
            ### other possible colors are red, green, blue, cyan, magenta, yellow, black, gray, darkgray, lightgray, brown, lime, olive, orange, pink, purple, teal, violet and white
        },
        Coordinates(x3, y3)
    ),
  LegendEntry(L"\Large{\mbox{EG-Alg2}}"),
    
        PlotInc(
        {
            #"no marks",
            "mark repeat=300",
            #mark="x",
            mark="diamond*",
            style = "{very thick}",
        },
        Coordinates(x4, y4)
    ),
  LegendEntry(L"\Large{\mbox{EG-Alg1}}")

)
# Out:
# Axis(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any,Any}("xmajorgrids" => nothing,"ymajorgrids" => nothing,"xlabel" => L"$\Large{\mbox{epoch}}$","ylabel" => L"$\Large{\mbox{Duality gap}}$","ymode" => "log","mark size=4pt" => nothing,"width" => "1\\textwidth","height" => "0.8\\textwidth","axis background/.style" => PGFPlotsX.Options(OrderedCollections.OrderedDict{Any,Any}("fill" => "gray!10"), true)), true), Any[Plot(false, true, PGFPlotsX.Options(OrderedCollections.OrderedDict{Any,Any}("mark repeat=1000" => nothing,"style" => "{very thick}"), true), Coordinates{2}(Union{Nothing, Coordinate{2}}[Coordinate{2}((1, 1.4919158340377847), nothing, nothing, nothing, nothing), Coordinate{2}((2, 1.191581008972151), nothing, nothing, nothing, nothing), Coordinate{2}((3, 1.1872582700151701), nothing, nothing, nothing, nothing), Coordinate{2}((4, 0.9394345966026711), nothing, nothing, nothing, nothing), Coordinate{2}((5, 0.9354641433526829), nothing, nothing, nothing, nothing), Coordinate{2}((6, 0.7934748166401322), nothing, nothing, nothing, nothing), Coordinate{2}((7, 0.7899071281913264), nothing, nothing, nothing, nothing), Coordinate{2}((8, 0.7014693868269599), nothing, nothing, nothing, nothing), Coordinate{2}((9, 0.6985172842944469), nothing, nothing, nothing, nothing), Coordinate{2}((10, 0.6477239112712472), nothing, nothing, nothing, nothing)  …  Coordinate{2}((991, 0.10597025605806176), nothing, nothing, nothing, nothing), Coordinate{2}((992, 0.10751792731835619), nothing, nothing, nothing, nothing), Coordinate{2}((993, 0.1073144384115543), nothing, nothing, nothing, nothing), Coordinate{2}((994, 0.10865396069110833), nothing, nothing, nothing, nothing), Coordinate{2}((995, 0.10844622756152744), nothing, nothing, nothing, nothing), Coordinate{2}((996, 0.1095737851336469), nothing, nothing, nothing, nothing), Coordinate{2}((997, 0.10936224803155215), nothing, nothing, nothing, nothing), Coordinate{2}((998, 0.11034895432941849), nothing, nothing, nothing, nothing), Coordinate{2}((999, 0.11013097326454102), nothing, nothing, nothing, nothing), Coordinate{2}((1000, 0.11097385267325022), nothing, nothing, nothing, nothing)]), Any[]), LegendEntry(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any,Any}(), false), L"$\Large{\mbox{EG}}$", false), Plot(false, true, PGFPlotsX.Options(OrderedCollections.OrderedDict{Any,Any}("mark repeat=200" => nothing,"style" => "{very thick}"), true), Coordinates{2}(Union{Nothing, Coordinate{2}}[Coordinate{2}((9.0, 1.4919158340377847), nothing, nothing, nothing, nothing), Coordinate{2}((18.0, 1.4919158340377847), nothing, nothing, nothing, nothing), Coordinate{2}((27.0, 0.5502006095890719), nothing, nothing, nothing, nothing), Coordinate{2}((36.0, 0.5056291186873105), nothing, nothing, nothing, nothing), Coordinate{2}((45.0, 0.29720492386936614), nothing, nothing, nothing, nothing), Coordinate{2}((54.0, 0.296491683383475), nothing, nothing, nothing, nothing), Coordinate{2}((63.0, 0.2214737427190323), nothing, nothing, nothing, nothing), Coordinate{2}((72.0, 0.22864488097389168), nothing, nothing, nothing, nothing), Coordinate{2}((81.0, 0.1657660128685141), nothing, nothing, nothing, nothing), Coordinate{2}((90.0, 0.1729805007916536), nothing, nothing, nothing, nothing)  …  Coordinate{2}((936.0, 0.00849171266654114), nothing, nothing, nothing, nothing), Coordinate{2}((945.0, 0.009146427700509108), nothing, nothing, nothing, nothing), Coordinate{2}((954.0, 0.008702672405206613), nothing, nothing, nothing, nothing), Coordinate{2}((963.0, 0.009723633150907185), nothing, nothing, nothing, nothing), Coordinate{2}((972.0, 0.00955129940832311), nothing, nothing, nothing, nothing), Coordinate{2}((981.0, 0.010009112583353685), nothing, nothing, nothing, nothing), Coordinate{2}((990.0, 0.009677666007110508), nothing, nothing, nothing, nothing), Coordinate{2}((999.0, 0.009284096694307742), nothing, nothing, nothing, nothing), Coordinate{2}((1008.0, 0.00905099994386438), nothing, nothing, nothing, nothing), Coor ...

# %% [markdown]
# #### Save all plots in different formats

# %%
base_name = chop(filename, tail=4)
pgfsave(string(base_name, "tex"), fig)
pgfsave(string(base_name, "tikz"), fig)
pgfsave(string(base_name, "pdf"), fig)

# %% [markdown]
# ### Bregman
# Load data

# %%
# load data 
probl = 1 # 1, 2 or 3
sd = "1"

if probl == 1
    A = Problems.policeman_and_burglar_matrix(n; seed=sd)
    filename = "save/probl_1b.jld2" 
elseif probl == 2
    A = Problems.nemirovski1(n)
    filename = "save/probl_2b.jld2" 
elseif probl == 3
    A = Problems.nemirovski2(n, 2)
    filename = "save/probl_3b.jld2" 
elseif probl == 4
    A = Problems.randunif(m, n; seed=sd)
    filename = "save/probl_4b.jld2"
    
end

@load filename res1 res2 res3
# Out:
# 3-element Array{Symbol,1}:
#  :res1
#  :res2
#  :res3

# %%
y1, y2, y3 = res1[1], res2[1], res3[1]
x1, x2, x3 = Array(1:length(y1)), res2[4], res3[4]


fig = @pgf Axis(
    {
        xmajorgrids, # show grids along x axis
        ymajorgrids, 
        xlabel = L"\Large{\mbox{epoch}}",  
        ylabel = L"\Large{\mbox{Duality gap}}",
        #xmode  = "log",
        ymode  = "log",
        "mark size=4pt",
        width = raw"1\textwidth",
        height = raw"0.8\textwidth",
        
        "axis background/.style" = { fill = "gray!10" }, 
   
    },
    PlotInc(
        {
            #"no marks",
            "mark repeat=2000",
            style = "{very thick}",
        },
        Coordinates(x1, y1)
    ), 
   LegendEntry(L"\Large{\mbox{MP}}"),
   
    PlotInc(
        {
            #"no marks",
            "mark repeat=50",
            style = "{very thick}",
        },
        Coordinates(x2, y2)
    ),
  LegendEntry(L"\Large{\mbox{MP-Car+19}}"),
    
       
    PlotInc(
        {
            #"no marks",
            "mark repeat=500",
            mark="triangle*",
            style = "{very thick}",
            color = "olive" 
            ### other possible colors are red, green, blue, cyan, magenta, yellow, black, gray, darkgray, lightgray, brown, lime, olive, orange, pink, purple, teal, violet and white
        },
        Coordinates(x3, y3)
    ),
  LegendEntry(L"\Large{\mbox{MP-Alg2}}"),

)
# Out:
# Axis(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any,Any}("xmajorgrids" => nothing,"ymajorgrids" => nothing,"xlabel" => L"$\Large{\mbox{epoch}}$","ylabel" => L"$\Large{\mbox{Duality gap}}$","ymode" => "log","mark size=4pt" => nothing,"width" => "1\\textwidth","height" => "0.8\\textwidth","axis background/.style" => PGFPlotsX.Options(OrderedCollections.OrderedDict{Any,Any}("fill" => "gray!10"), true)), true), Any[Plot(false, true, PGFPlotsX.Options(OrderedCollections.OrderedDict{Any,Any}("mark repeat=2000" => nothing,"style" => "{very thick}"), true), Coordinates{2}(Union{Nothing, Coordinate{2}}[Coordinate{2}((1, 1.4919158340377847), nothing, nothing, nothing, nothing), Coordinate{2}((2, 1.1817017325642403), nothing, nothing, nothing, nothing), Coordinate{2}((3, 1.1743935937763212), nothing, nothing, nothing, nothing), Coordinate{2}((4, 0.9126387798026963), nothing, nothing, nothing, nothing), Coordinate{2}((5, 0.8950438686857061), nothing, nothing, nothing, nothing), Coordinate{2}((6, 0.772690194831859), nothing, nothing, nothing, nothing), Coordinate{2}((7, 0.7426585233302117), nothing, nothing, nothing, nothing), Coordinate{2}((8, 0.6647477560032109), nothing, nothing, nothing, nothing), Coordinate{2}((9, 0.6234166889955053), nothing, nothing, nothing, nothing), Coordinate{2}((10, 0.6229958393639974), nothing, nothing, nothing, nothing)  …  Coordinate{2}((991, 0.0026434189443977907), nothing, nothing, nothing, nothing), Coordinate{2}((992, 0.0027238968705525224), nothing, nothing, nothing, nothing), Coordinate{2}((993, 0.0026684945428840923), nothing, nothing, nothing, nothing), Coordinate{2}((994, 0.002691938110467529), nothing, nothing, nothing, nothing), Coordinate{2}((995, 0.0026360926188901956), nothing, nothing, nothing, nothing), Coordinate{2}((996, 0.0026033683622961323), nothing, nothing, nothing, nothing), Coordinate{2}((997, 0.002548358527323602), nothing, nothing, nothing, nothing), Coordinate{2}((998, 0.00246158721441625), nothing, nothing, nothing, nothing), Coordinate{2}((999, 0.0024086245828720543), nothing, nothing, nothing, nothing), Coordinate{2}((1000, 0.002271078074340016), nothing, nothing, nothing, nothing)]), Any[]), LegendEntry(PGFPlotsX.Options(OrderedCollections.OrderedDict{Any,Any}(), false), L"$\Large{\mbox{MP}}$", false), Plot(false, true, PGFPlotsX.Options(OrderedCollections.OrderedDict{Any,Any}("mark repeat=50" => nothing,"style" => "{very thick}"), true), Coordinates{2}(Union{Nothing, Coordinate{2}}[Coordinate{2}((21.01, 1.4919158340377847), nothing, nothing, nothing, nothing), Coordinate{2}((42.02, 1.4919158340377847), nothing, nothing, nothing, nothing), Coordinate{2}((63.03, 0.25136200331511604), nothing, nothing, nothing, nothing), Coordinate{2}((84.04, 0.32943058941718983), nothing, nothing, nothing, nothing), Coordinate{2}((105.05000000000001, 0.0715229090348295), nothing, nothing, nothing, nothing), Coordinate{2}((126.06, 0.1121382514039706), nothing, nothing, nothing, nothing), Coordinate{2}((147.07000000000002, 0.06574717172626054), nothing, nothing, nothing, nothing), Coordinate{2}((168.08, 0.046161615674944034), nothing, nothing, nothing, nothing), Coordinate{2}((189.09, 0.05774536231960403), nothing, nothing, nothing, nothing), Coordinate{2}((210.10000000000002, 0.04881557917357493), nothing, nothing, nothing, nothing)  …  Coordinate{2}((840.4000000000001, 3.947209641141924e-6), nothing, nothing, nothing, nothing), Coordinate{2}((861.4100000000001, 3.0441392915303567e-6), nothing, nothing, nothing, nothing), Coordinate{2}((882.4200000000001, 2.483007214060251e-6), nothing, nothing, nothing, nothing), Coordinate{2}((903.4300000000001, 1.8450802374836428e-6), nothing, nothing, nothing, nothing), Coordinate{2}((924.44, 1.7868342219173883e-6), nothing, nothing, nothing, nothing), Coordinate{2}((945.45, 1.419459328966255e-6), nothing, nothing, nothing, nothing), Coordinate{2}((966.46, 8.910797903993739e-7), nothing, nothing, nothing, nothing), Coordinate{2}((987.47, 1.068361119571 ...

# %%
base_name = chop(filename, tail=4)
pgfsave(string(base_name, "tex"), fig)
pgfsave(string(base_name, "tikz"), fig)
pgfsave(string(base_name, "pdf"), fig)
